# %% [markdown]
# <a href="https://colab.research.google.com/github/Sabra7/py_labs/blob/main/lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 4.2 Defining Functions
# Write a function named greet that prints "**Welcome to Python!**" when called.

# %%
def greeting():
  print("Welcom to Pythone!")
# to use the Function
greeting()
# Out:
# Welcom to Pythone!

# %% [markdown]
# # 4.3 Functions with Multiple Parameters
# Write a function that accepts two numbers and prints their sum.

# %%
def sum_two():
  number1, number2 = int(input("Enter the first number to sum:")),  int(input("Enter the second number to sum:"))
  return number1 + number2
  print(number1 + number2)

sum_two()
# Out:
# Enter the first number to sum:1
# Enter the second number to sum:4
# 5

# %% [markdown]
# #4.4 Random-Number Generation
# Write a program that generates and prints a random integer between **1 and 100**.

# %%
import random as rd

# %%
for random_number in range(10):
  print ( rd.randrange(1, 100))
# Out:
# 69
# 54
# 64
# 83
# 1
# 96
# 69
# 14
# 7
# 81

# %% [markdown]
# #4.7 math Module Functions
# Write a program that reads a number and prints its square root using the math module.

# %%
import math

# %%
print(pow(int(input("Enter a number to be squared ")), 2))
# Out:
# Enter a number to be squared 5
# 25

# %% [markdown]
# #4.9 Default Parameter Values
# Write a function that prints a greeting with a default name of **"Guest"**.

# %%
def greet(name="Guest"):
  print(f"Hello and GoodBye {name}")

greet()
# Out:
# Hello and GoodBye Guest

# %% [markdown]
# #4.10 Keyword Arguments
# Write a function with two parameters and call it using keyword arguments.

# %%
def print_your_FullName(Father_name="your father", Name="Your name"):
  print(f"My full name is {Name} {Father_name}")

print_your_FullName(Name= "Mohammed", Father_name="Saeed")
# Out:
# My full name is Mohammed Saeed

# %% [markdown]
# #4.11 Arbitrary Argument Lists
# Write a function that accepts any number of integers and prints their sum.

# %%
def sum_Numbers(*Numbers):
  print(sum(Numbers))
X = [i+1 for i in range(10)]
sum_Numbers(*X)
# Out:
# 55

# %% [markdown]
# #4.12 Methods: Functions That Belong to Objects
# Write a program that converts a string to uppercase using a string method.

# %%
hi = "hello world"

# %%
hi.upper()
# Out:
# 'HELLO WORLD'

# %% [markdown]
# #4.13 Scope Rules
# Write a program that demonstrates the difference between a local variable and a global variable.

# %%
A = "I am globle"

def test_scope():
  B = "i am local"
  print(B)

# %%
print(A)
test_scope()
# Out:
# I am globle
# i am local

# %% [markdown]
# #4.14 import: A Deeper Look
# Write a program that imports only the sqrt function from the math module and uses it.

# %%
from math import sqrt

# %%
Q = sqrt(2)
print(Q)
# Out:
# 1.4142135623730951

# %% [markdown]
# #4.15 Passing Arguments to Functions
# A Deeper Look: Write a function that receives a list and prints its first element.

# %%
numbers = [10, 20, 30, 40]
def print_first_element(my_list):
  print(my_list[0])

print_first_element(numbers)
# Out:
# 10

# %% [markdown]
# #4.16 Function-Call Stack
# Write two functions where one function calls the other and prints a  message.

# %%
def function_b():
  print("Inside Function B")

def function_a():
  print("Starting Function A")
  function_b()
  print("Ending Function A")

# %%
function_a()
# Out:
# Starting Function A
# Inside Function B
# Ending Function A
