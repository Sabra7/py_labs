# %% [markdown]
# <a href="https://colab.research.google.com/github/Sabra7/py_labs/blob/main/lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 2.2 Varibales and assignment statements

# %%
Name = input("Enter your name ")
Age = int(input("Enter your age "))

print( f"your name is {Name} and your age are {Age}")
# Out:
# Enter your name Mohammed
# Enter your age 20
# your name is Mohammed and your age are 20

# %% [markdown]
# 2.3 Arithmetic

# %%
Num_1 = int(input(" Enter the first number to sum "))
Num_2 = int(input(" Enter the second number to sum "))

print(" The Results equal to, ", Num_1 + Num_2)
# Out:
#  Enter the first number to sum 4
#  Enter the second number to sum 7
#  The Results equal to,  11

# %% [markdown]
# 2.4 Function print() and String

# %%
print(' She said, "Python is fun!"')
# Out:
#  She said, "Python is fun!"

# %% [markdown]
# 2.5 Triple Quoted String

# %%
print("""Welcom
To
Python """)
# Out:
# Welcom
# To
# Python

# %% [markdown]
# 2.6 Getting input from the User

# %%
User_name = input("Enter your name ")
print(f" Greeting {User_name} and have fun")
# Out:
# Enter your name Mohammed
#  Greeting Mohammed and have fun

# %% [markdown]
# 2.7 if Statement and Comparison Operators

# %%
Pos_num = int(input("Enter the num "))
if Pos_num <= 0 :
    print("Not positive")
else :
    print("positive")
# Out:
# Enter the num 0
# Not positive

# %% [markdown]
# 2.8 Objecs and Dynamic Typing

# %%
X = 3
print(type(X))

Y = str(X)
print(type(Y))
# Out:
# <class 'int'>
# <class 'str'>
